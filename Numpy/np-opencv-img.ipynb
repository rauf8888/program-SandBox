# %%
import cv2
image_path = "image.jpeg"
img = cv2.imread(image_path)

print(img)
print(type(img))
img.shape
# Out:
# [[[190 149  86]
#   [171 130  67]
#   [177 132  71]
#   ...
#   [194 151  94]
#   [186 140  86]
#   [174 128  74]]
#
#  [[169 128  66]
#   [157 116  54]
#   [164 120  61]
#   ...
#   [194 154  95]
#   [188 145  88]
#   [181 136  79]]
#
#  [[135  94  39]
#   [135  94  39]
#   [142  98  44]
#   ...
#   [201 164 104]
#   [198 159  97]
#   [195 154  92]]
#
#  ...
#
#  [[ 37   9   0]
#   [ 37   9   0]
#   [ 37   8   0]
#   ...
#   [ 43  14   0]
#   [ 45  14   0]
#   [ 45  14   0]]
#
#  [[ 49  11   0]
#   [ 49  11   0]
#   [ 46  10   0]
#   ...
#   [ 43  17   3]
#   [ 44  17   3]
#   [ 44  17   3]]
#
#  [[ 55  11   0]
#   [ 53  11   0]
#   [ 52   9   0]
#   ...
#   [ 41  18   3]
#   [ 43  17   3]
#   [ 43  17   3]]]
# <class 'numpy.ndarray'>
# (194, 259, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
plt.imshow(img[::-1])

# %%
plt.imshow(img[:,::-1])

# %%
plt.imshow(img[25:100,100:150])

# %%
plt.imshow(img[::2,::2])

# %%
import numpy as np
img_sin = np.sin(img)
img_sin
# Out:
# array([[[ 0.9976 , -0.9746 , -0.9233 ],
#         [ 0.9766 , -0.93   , -0.8555 ],
#         [ 0.8774 ,  0.05307,  0.951  ],
#         ...,
#         [-0.702  ,  0.2021 , -0.2452 ],
#         [-0.602  ,  0.9805 , -0.9233 ],
#         [-0.9365 ,  0.721  , -0.9854 ]],
#
#        [[-0.602  ,  0.721  , -0.02655],
#         [-0.0795 ,  0.2367 , -0.5586 ],
#         [ 0.5947 ,  0.5806 , -0.9663 ],
#         ...,
#         [-0.702  , -0.06192,  0.683  ],
#         [-0.4756 ,  0.4678 ,  0.0354 ],
#         [-0.9365 , -0.7905 , -0.444  ]],
#
#        [[ 0.0884 , -0.2452 ,  0.964  ],
#         [ 0.0884 , -0.2452 ,  0.964  ],
#         [-0.588  , -0.573  ,  0.0177 ],
#         ...,
#         [-0.0619 ,  0.5947 , -0.3215 ],
#         [-0.0796 ,  0.9395 ,  0.3796 ],
#         [ 0.2195 , -0.06192, -0.7793 ]],
#
#        ...,
#
#        [[-0.6436 ,  0.412  ,  0.     ],
#         [-0.6436 ,  0.412  ,  0.     ],
#         [-0.6436 ,  0.9893 ,  0.     ],
#         ...,
#         [-0.8315 ,  0.9907 ,  0.     ],
#         [ 0.851  ,  0.9907 ,  0.     ],
#         [ 0.851  ,  0.9907 ,  0.     ]],
#
#        [[-0.9536 , -1.     ,  0.     ],
#         [-0.9536 , -1.     ,  0.     ],
#         [ 0.902  , -0.544  ,  0.     ],
#         ...,
#         [-0.8315 , -0.9614 ,  0.1411 ],
#         [ 0.0177 , -0.9614 ,  0.1411 ],
#         [ 0.0177 , -0.9614 ,  0.1411 ]],
#
#        [[-0.9995 , -1.     ,  0.     ],
#         [ 0.396  , -1.     ,  0.     ],
#         [ 0.987  ,  0.412  ,  0.     ],
#         ...,
#         [-0.1586 , -0.751  ,  0.1411 ],
#         [-0.8315 , -0.9614 ,  0.1411 ],
#         [-0.8315 , -0.9614 ,  0.1411 ]]], dtype=float16)

# %%
print(np.sum(img_sin),'\n',
np.mean(img_sin),'\n',
np.median(img_sin),'\n',
np.min(img_sin),'\n',
np.max(img_sin),'\n',
np.argmax(img_sin))
# Out:
# 501.5
#  0.003338
#  0.0
#  -1.0
#  1.0
#  14

# %%
arr = np.array([3,6,9,12,15])
arr<10
# Out:
# array([ True,  True,  True, False, False])

# %%
arr>10
# Out:
# array([False, False, False,  True,  True])

# %%
arr[arr>10]
# Out:
# array([12, 15])

# %%
masked_img = np.where(img > 100,255,0)
plt.imshow(masked_img)

# %%
masked_img = np.where(img > 230,255,0)
plt.imshow(masked_img)
